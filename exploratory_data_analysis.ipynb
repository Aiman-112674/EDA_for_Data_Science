# %% [markdown]
# #EDA--it is drawing facts from data , exploring data
# ### Exploratory Data Anaylsis

# %% [markdown]
# # 1- DAY--1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Import Dataset

# %%
df= sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 2. Bigger picture of data ---Understranding Data

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# #2. finding missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum() #finding missing or null values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # 2 . if a column in resulting giving more then 75 % so we remove it -- column

# %%
# calculating percentage of null value

df.isnull().sum()*100/len(df)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# # 2. age=19% which is less then 30 or 40 % so try to impute or replace the missing values by drawing the
# *Mean
# *Median
# *Mode
# from any on this we can replace all the age missing values in rows

# %% [markdown]
# # How to deal with missing values in EDA analysis -- Assignment
# *Categorical --object
# *numerical -- int or float
# *Boolean--True or false

# %%
df['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['age'].max()
# Out:
# 80.0

# %%
print(df['age'].mean())
print(df['age'].median())
print(df['age'].mode())
# Out:
# 29.69911764705882
# 28.0
# 0    24.0
# Name: age, dtype: float64

# %%
df['age'].min()
# Out:
# 0.42

# %%
df2=df['age'].fillna(df['age'].mean())
# df2.isnull().sum()
df2
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
df2.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # now apply samething on Fare but using diff technique

# %%
df2[age].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1431988646.py in <cell line: 0>()
# ----> 1 df2[age].unique()
#
# NameError: name 'age' is not defined

# %%
df3=df2

# %%
df3.isnull()

# %%
df3.drop(columns=['deck'])

# %%
# df4 = df3
df4['embark_town'].fillna(df4['embark_town'].mode()[0],inplace=True)
df4['embarked'].fillna(df4['embarked'].mode()[0],inplace=True)
df4

# %% [markdown]
# # .mean=average --- plus all values and then divide with total no of frenquency
# # . median = if we have 5 values then the 3    is the median but 1st make teh ascending or decending order but if they number is 6 so we plus the 1,2,3,4,5,6 -- 3 and 4 and then divide it by 2.
# # .mode = most frequent value

# %%
print('mean = ' , df['age'].mean())
print('median= ',df['age'].median())
print('mode= ',df['embarked'].mode())

# %%
df

# %% [markdown]
# #steps: Data Wrangling(cleaning data from outliers , normalizing , missing NAN values )(EDA)
# 1. import libraries
# 2. import dataset
# 3. explore your data
#      1. Information
#      2. Datatypes
#      3. Missing Values
#      4. Take sense of your data
# 4. Understanding the variables
# 5. Relationship between the variables (Heatmap, Pairplot , correlation)
# 6. Brainstorming
#      1. Normalize (Techniques of normalizing -- Assignment)
#      2. Removing outliers (what and how to remove)
# 7. Tidy or clean data then above 6 steps
# 8. ready for Statistical analysis
# 9. Ready for prediction
# 10. ready for machine learning
# 11. ready for deep learning

# %% [markdown]
# # DAY--2

# %% [markdown]
# EDA
# #Exploratory Data Analysis
# method to analyze and summarize
# using pandas to Do EDA

# %% [markdown]
# # 1-- Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2-- import dataset

# %%
df=sns.load_dataset("titanic")

# %% [markdown]
# Analyze and summarize

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
# summarize (summary statistics)
df.describe()  # numerical variables only

# %%
# how to find null vales
df.isnull()  #boolean values -- null=true , no null= false

# %%
# how to find NAN values
df.isnull().sum()

# %%
# how to find % of each variable
# len--- length of data frame
df.isnull().sum()*100/len(df)

# %%
#nunique-- number of unique values
#if unique values for a particular varible is greater then 10 then its a numerical variable
df.nunique()

# %%
df.columns

# %%
# visualize the NAN values in Heatmap
#cmap--color map
#cbar--color bar --True
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#how to remove deck from the df
df.drop(columns=['deck'], inplace=True)

# %%
# checking if deck removed -- deck is removed due to NAN
df.columns

# %%
#visualization and explore
#count plot -- cannot include y in this beacuse on y-axis already counting for the specified x variable is persent .
sns.countplot(x='survived', data=df)

# %%
sns.barplot(x='survived' , y='fare' , hue='who' ,data=df)

# %%
sns.countplot(x='pclass', data=df)

# %%
sns.barplot(x='sex',y='age' ,hue='who', data=df)

# %%
sns.countplot(x='pclass' , data=df,hue='who')

# %% [markdown]
# EDA--is analyzing and summarzing

# %% [markdown]
# #data distribution --how data distribute

# %%
# bins --- in order standing
sns.histplot(data=df,x='age' , bins=30)

# %%
# alpha = color shade how much want to strong
df['age'].hist(bins=30, color='red',alpha=0.7)

# %%
#box plot
sns.boxplot(data=df,y='age')

# %%
#box plot
sns.boxplot(data=df,x='age')

# %%
sns.boxplot(x='age',y='fare' , data=df)

# %% [markdown]
# #--- for thinking
# # -- can two numerical variable plot on boxplot
# #--- Ans: whenever we draw a boxplot always take on one axis numerical variable and on the other axis take categorical variable as in the below example
#
# # --- same for barplot

# %%
sns.boxplot(data=df,y='age',x='survived', hue ='who')

# %%
sns.boxplot(data=df,x='who',y='age',hue='survived')

# %%
#scatter plot
sns.scatterplot(x='age',y='fare',data=df,hue='pclass')
plt.ylim(0,250)

# %%
sns.pairplot(df,hue='survived')

# %%
#stacked barchart/plot
df.groupby(['pclass','sex'])['survived'].mean().unstack().plot(kind='bar',stacked=True)

# %%
df.groupby(['pclass','who'])['fare'].mean().unstack().plot(kind='bar',stacked=True)

# %% [markdown]
# how to change the position of x -axis tik in matplotlib 1,2,3

# %%
#swarm-- categorical data
sns.swarmplot(x='survived',y='fare',data=df,hue='who')

# %%
sns.swarmplot(x='survived',y='age',data=df,hue='who')

# %%
#point plot
sns.catplot(x='pclass',y='fare',hue='embarked',kind='point',data=df)

# %%
#realtion of two numeric variables
sns.lmplot(data=df,y='fare',x='age')
plt.ylim(0,200)
plt.xlim(0,40)

# %%
sns.lmplot(data=df,y='fare',x='age')

# %%
sns.lmplot(data=df,x='fare',y='age')

# %%
# how to add a column and make a age group
# sns.histplot(data=df,x='age')
#grouping
df.columns

# %%
df['age_groups']=pd.cut(df['age'],[0,10,18,30,50,80],labels=['kids','child','youth','middle child','old'])
df.head()

# %%
df.columns

# %%
df.groupby("age_groups")['fare'].mean().plot(kind='bar')

# %%
sns.pairplot(data=df,hue='survived',vars=['age','fare','pclass'])

# %% [markdown]
# #family_size

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.pairplot(data=df,hue='survived',vars=['sibsp','parch'])
